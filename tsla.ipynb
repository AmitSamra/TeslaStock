# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
tsla = yf.Ticker("TSLA")
tsla.info
# Out:
# {'zip': '94304',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 48016,
# ...

# %%
hist = tsla.history(start="2019-01-01", end="2020-12-01")
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2019-01-02   61.220001   63.026001   59.759998   62.023998  58293000
# 2019-01-03   61.400002   61.880001   59.476002   60.071999  34826000
# 2019-01-04   61.200001   63.599998   60.546001   63.537998  36970500
# 2019-01-07   64.344002   67.348000   63.549999   66.991997  37756000
# 2019-01-08   68.391998   68.802002   65.403999   67.070000  35042500
# ...                ...         ...         ...         ...       ...
# 2020-11-23  503.500000  526.000000  501.790009  521.849976  50260300
# 2020-11-24  540.400024  559.989990  526.200012  555.380005  53648500
# 2020-11-25  550.059998  574.000000  545.369995  574.000000  48930200
# 2020-11-27  581.159973  598.780029  578.450012  585.760010  37561100
# 2020-11-30  602.210022  607.799988  554.510010  567.599976  63003100
#
#             Dividends  Stock Splits
# Date
# 2019-01-02          0           0.0
# 2019-01-03          0           0.0
# ...

# %%
df_tsla = hist
df_tsla = df_tsla.reset_index()
df_tsla.columns = df_tsla.columns.str.replace(' ', '').str.lower()
df_tsla = df_tsla.rename(columns={'stocksplits':'stock_splits'})
df_tsla['change'] = df_tsla['close']-df_tsla['close'].shift(1)
df_tsla['percent_change'] = (df_tsla['close']/df_tsla['close'].shift(1))-1
df_tsla['market_cap'] = df_tsla['close']*df_tsla['volume']/1000000
df_tsla[['open','high','low','close','change']] = df_tsla[['open','high','low','close','change']].round(2)
df_tsla[['percent_change']] = df_tsla[['percent_change']].round(4)
df_tsla[['market_cap']] = df_tsla[['market_cap']].round(1)
#df_tsla = df_tsla[['date','open','high','low','close','change','percent_change','volume','market_cap','stock_splits']]
df_tsla
# Out:
#           date    open    high     low   close    volume  dividends  \
# 0   2019-01-02   61.22   63.03   59.76   62.02  58293000          0
# 1   2019-01-03   61.40   61.88   59.48   60.07  34826000          0
# 2   2019-01-04   61.20   63.60   60.55   63.54  36970500          0
# 3   2019-01-07   64.34   67.35   63.55   66.99  37756000          0
# 4   2019-01-08   68.39   68.80   65.40   67.07  35042500          0
# ..         ...     ...     ...     ...     ...       ...        ...
# 478 2020-11-23  503.50  526.00  501.79  521.85  50260300          0
# 479 2020-11-24  540.40  559.99  526.20  555.38  53648500          0
# 480 2020-11-25  550.06  574.00  545.37  574.00  48930200          0
# 481 2020-11-27  581.16  598.78  578.45  585.76  37561100          0
# 482 2020-11-30  602.21  607.80  554.51  567.60  63003100          0
#
#      stock_splits  change  percent_change  market_cap
# 0             0.0     NaN             NaN      3615.6
# ...
